# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:/Users/manoj/OneDrive/Desktop/TASK/student_data.csv")
data = data.drop(['Dalc', 'famsize', 'Walc','health','famrel','freetime','G1','G2','G3','goout','romantic'], axis=1)


data.head(5)
# Out:
#   school sex  age address Pstatus  Medu  Fedu     Mjob      Fjob  reason  ...  \
# 0     GP   F   18       U       A     4     4  at_home   teacher  course  ...
# 1     GP   F   17       U       T     1     1  at_home     other  course  ...
# 2     GP   F   15       U       T     1     1  at_home     other   other  ...
# 3     GP   F   15       U       T     4     2   health  services    home  ...
# 4     GP   F   16       U       T     3     3    other     other    home  ...
#
#   studytime  failures  schoolsup  famsup paid activities nursery higher  \
# 0         2         0        yes      no   no         no     yes    yes
# 1         2         0         no     yes   no         no      no    yes
# 2         2         3        yes      no  yes         no     yes    yes
# 3         3         0         no     yes  yes        yes     yes    yes
# 4         2         0         no     yes  yes         no     yes    yes
#
#   internet absences
# 0       no        6
# 1      yes        4
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))

plt.hist(data['age'], bins=6, alpha=0.8, label='Age', color='blue')
plt.hist(data['sex'], bins=3, alpha=1, label='sex', color='red')

plt.xlabel('Observation')
plt.ylabel('Frequency')
plt.title('Histogram of Age and sex')
plt.legend()
plt.show()
